# %% [markdown]
# <a href="https://colab.research.google.com/github/f4elz/ifood-crm-bi-case/blob/main/notebook_m1_etl.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ================================================
# CÉLULA 4 — Primeiro commit (salvar no GitHub)
# ================================================

# 1. Ver o que mudou
# !git status

# 2. Adicionar TUDO que mudou
# !git add .

# 3. Criar um "save point" com mensagem descritiva
# !git commit -m "feat: estrutura inicial do projeto"

# 4. Enviar para o GitHub
# !git push origin main
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# Everything up-to-date
